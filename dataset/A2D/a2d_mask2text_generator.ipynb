# %%
import pandas as pd
import os
import re
import h5py
from PIL import Image
import matplotlib.pyplot as plt
import json

# %%
# Load CSV file
csv_path = '/workspace/LLaSA/dataset/A2D/a2d_annotation.csv' 
csv_data = pd.read_csv(csv_path)

# Base paths for videos and annotations
video_base_path = '/workspace/LLaSA/dataset/A2D/clips320jpeg/' # Replace with your base video directory
annotation_base_path = '/workspace/LLaSA/dataset/A2D/Annotations/mat/'  # Replace with your base annotation directory

# %%
# Dictionary to store collected information
video_info_dict = {}
bullshit = 0

# Iterate through the rows in the CSV file
for index, row in csv_data.iterrows():
    video_id = row['video_id']
    instance_id = int(re.sub(r'\D', '', str(row['instance_id'])))
    caption = row['query']

    # Construct path to the video file
    video_path = os.path.join(video_base_path, f"{video_id}")
    
    # Find all annotation files in the annotation directory
    annotation_files = []
    annotation_dir = os.path.join(annotation_base_path, video_id)
    for root, dirs, files in os.walk(annotation_dir):
        for file in files:
            if file.endswith('.mat'):
                annotation_files.append(os.path.join(root, file))
    if annotation_files:
        # Extract frame numbers from the file names and find the smallest one
        annotation_files_sorted = sorted(annotation_files, key=lambda x: int(os.path.basename(x).split('.')[0]))
        smallest_frame_annotation = annotation_files_sorted[0]
        
        # Extract the frame number from the file name
        bbox_frame = int(os.path.basename(smallest_frame_annotation).split('.')[0])
        
        # Load annotation data using h5py
        with h5py.File(smallest_frame_annotation, 'r') as f:
            if 'reBBox' in f:
                bbox_list = f['reBBox'][:] # Read and convert to list

                if instance_id >= bbox_list.shape[1]:
                    bullshit += 1
                    print(f'{video_id} passed since {instance_id} >= {bbox_list.shape[1]}')
                    continue

                bbox = tuple(sub_list[instance_id] for sub_list in bbox_list)
            else:
                bbox = None
                print(f"Bounding box 'reBBox' not found in file: {smallest_frame_annotation}")
        
        # Create a unique key for each entry
        entry_key = f"{video_id}_{index}"
        
        # Store the collected information in the dictionary
        video_info_dict[entry_key] = {
            "video": video_path,
            "bbox_frame": bbox_frame,
            "bbox": bbox,
            "caption": caption
        }
    else:
        print(f"No annotation files found in the directory: {annotation_dir}")

# Dump the collected information into a JSON file
output_json_path = 'output_video_info.json'  # Specify your output JSON file path
with open(output_json_path, 'w') as json_file:
    json.dump(video_info_dict, json_file, indent=4)

print(f"Collected video information saved to {output_json_path}")
print(f'{bullshit}')
# Out:
# -0cOo0cRVZU passed since 7 >= 7
# -2akYw9VucA passed since 2 >= 2
# -2akYw9VucA passed since 3 >= 2
# -2akYw9VucA passed since 4 >= 2
# -2akYw9VucA passed since 5 >= 2
# -8FLF-osZmA passed since 4 >= 4
# 0S0aQ0GArRc passed since 7 >= 7
# 0S0aQ0GArRc passed since 8 >= 7
# 0S0aQ0GArRc passed since 9 >= 7
# 10XCfvnVUL0 passed since 4 >= 4
# 10XCfvnVUL0 passed since 5 >= 4
# 157RAPLxUpQ passed since 1 >= 1
# 19dJTBEjS8Q passed since 1 >= 1
# 1Am_eZhq0wg passed since 1 >= 1
# 1DX-aZNP5NQ passed since 3 >= 3
# 1Fmmpda6-Z8 passed since 4 >= 4
# 1TY6VJH-wqY passed since 1 >= 1
# 1f19vXJMH44 passed since 1 >= 1
# 2G9DODKHHIM passed since 4 >= 4
# 3CcQVREqgPM passed since 2 >= 2
# 3kntCqeudw0 passed since 1 >= 1
# 3kntCqeudw0 passed since 2 >= 1
# 3zsM3jBwWIM passed since 3 >= 3
# 4ez0EQpnUW8 passed since 3 >= 3
# 4ltpjuovmPM passed since 2 >= 2
# 4xNTw6cEicA passed since 1 >= 1
# 58rYwU1Rnpw passed since 5 >= 5
# 5DEOQzI8_Mc passed since 2 >= 2
# 5MgnA8i9GJE passed since 3 >= 3
# 5X3tJQtytiU passed since 1 >= 1
# 5_ONVWEUAcg passed since 1 >= 1
# 64YpE9Pgsgk passed since 1 >= 1
# 6JMh_oA23EU passed since 2 >= 2
# 6KAonV0ej4c passed since 1 >= 1
# 6KAonV0ej4c passed since 2 >= 1
# 6YIdUkJO7TA passed since 2 >= 2
# 6gwZ6MPYW_Y passed since 3 >= 3
# 6hDL1unsEIg passed since 1 >= 1
# 6hDL1unsEIg passed since 2 >= 1
# 6sGQPMg4Gqc passed since 1 >= 1
# 77CtRWUggp4 passed since 2 >= 2
# 77CtRWUggp4 passed since 3 >= 2
# 77CtRWUggp4 passed since 4 >= 2
# 77CtRWUggp4 passed since 5 >= 2
# 77CtRWUggp4 passed since 6 >= 2
# 77CtRWUggp4 passed since 7 >= 2
# 7ZICknA76oI passed since 2 >= 2
# 7bud84dpeXo passed since 4 >= 4
# 7kV4-ziw4pU passed since 1 >= 1
# 7kuUHEyCV9g passed since 1 >= 1
# 7kuUHEyCV9g passed since 2 >= 1
# 84hC_geiftQ passed since 4 >= 4
# 84hC_geiftQ passed since 5 >= 4
# 866n2kjpwT8 passed since 1 >= 1
# 866n2kjpwT8 passed since 2 >= 1
# 866n2kjpwT8 passed since 3 >= 1
# 866n2kjpwT8 passed since 4 >= 1
# 866n2kjpwT8 passed since 5 >= 1
# 86I-9-tRdvg passed since 2 >= 2
# 86I-9-tRdvg passed since 3 >= 2
# 8IJbjyyuQ0w passed since 2 >= 2
# 8KlUJxetz3k passed since 4 >= 4
# 8RWcDBWxJao passed since 3 >= 3
# 8chfC1_ip0E passed since 3 >= 3
# 8chfC1_ip0E passed since 4 >= 3
# 8eejc0p7nCM passed since 1 >= 1
# 8mY8Yechvg8 passed since 2 >= 2
# 8ybXnSkqayY passed since 5 >= 5
# 8ybXnSkqayY passed since 6 >= 5
# 9p-QoyTEgIA passed since 3 >= 3
# 9p-QoyTEgIA passed since 4 >= 3
# 9x68vNHF-Q0 passed since 1 >= 1
# 9zmCP8S2OeI passed since 1 >= 1
# AGiNjsXN9Nc passed since 3 >= 3
# AMRIatLZjz8 passed since 11 >= 11
# AMRIatLZjz8 passed since 12 >= 11
# AMRIatLZjz8 passed since 13 >= 11
# AMRIatLZjz8 passed since 14 >= 11
# AMRIatLZjz8 passed since 15 >= 11
# ASwQSR-YkvQ passed since 1 >= 1
# Aol8inp7OaU passed since 1 >= 1
# AtY35OB7ZQs passed since 1 >= 1
# BVZ90KGQV1o passed since 3 >= 3
# CIKdg6TAUIM passed since 2 >= 2
# CIKdg6TAUIM passed since 3 >= 2
# CTAKpizCcx4 passed since 1 >= 1
# CaWTbs0aMA8 passed since 3 >= 3
# CmY1DHiHEjs passed since 1 >= 1
# DEvM7I34_PM passed since 3 >= 3
# DLjnKcX8gvo passed since 1 >= 1
# DPF2qOq2YxI passed since 2 >= 2
# DRUAiHWWLRQ passed since 3 >= 3
# DVQo9PmELdg passed since 1 >= 1
# ELEb2IoCMec passed since 2 >= 2
# EXPOfStElLA passed since 2 >= 2
# EadxBPmQvtg passed since 11 >= 11
# EcaXVl4ThQ8 passed since 1 >= 1
# EymTVMtZSZc passed since 3 >= 3
# EzXkvol_K2g passed since 2 >= 2
# EzXkvol_K2g passed since 3 >= 2
# F5wcCnrUbvs passed since 1 >= 1
# FGD0lmAkJGg passed since 5 >= 5
# FGD0lmAkJGg passed since 6 >= 5
# FtqgsJwG5cE passed since 1 >= 1
# GEP-KgJkYnw passed since 3 >= 3
# GEc2wQLYQVk passed since 1 >= 1
# GJxqkwTb5LA passed since 2 >= 2
# G_d2QMCW0zg passed since 1 >= 1
# G_d2QMCW0zg passed since 2 >= 1
# G_d2QMCW0zg passed since 3 >= 1
# Gc8PVFQXL68 passed since 1 >= 1
# Gs_ViAd-Cgg passed since 1 >= 1
# Gs_ViAd-Cgg passed since 2 >= 1
# GwMmqd07TnE passed since 1 >= 1
# H0MjkAHV1ww passed since 7 >= 7
# HAIns-56tz0 passed since 1 >= 1
# HAIns-56tz0 passed since 2 >= 1
# HAIns-56tz0 passed since 3 >= 1
# HAIns-56tz0 passed since 4 >= 1
# HUemh6JnlAs passed since 2 >= 2
# HcIFZXaoRM0 passed since 1 >= 1
# HcKdMlDkLY4 passed since 1 >= 1
# ICvrQsxxebk passed since 2 >= 2
# IJ17Iynidxg passed since 1 >= 1
# ITk_WcP-8xg passed since 1 >= 1
# IcowgRlM-hE passed since 1 >= 1
# IlyMUOfW6Ko passed since 1 >= 1
# IvQ7UmztjC0 passed since 1 >= 1
# IvRZz2odxA0 passed since 8 >= 8
# J10axcxQs8k passed since 5 >= 5
# JC0xI9nb54Y passed since 1 >= 1
# JE0r0xPfBGU passed since 2 >= 2
# JIRCCthKAh0 passed since 4 >= 4
# JIRCCthKAh0 passed since 5 >= 4
# JNziEdeT3hU passed since 3 >= 3
# JgUBrgYXEMU passed since 2 >= 2
# Jq37leMMy_g passed since 3 >= 3
# Jq37leMMy_g passed since 4 >= 3
# JrGZd2wlFbM passed since 10 >= 9
# JrGZd2wlFbM passed since 9 >= 9
# KZEyKGWGSJc passed since 7 >= 7
# KZEyKGWGSJc passed since 8 >= 7
# LIQUed8AWRM passed since 4 >= 4
# LMqpv0abR7o passed since 6 >= 6
# LMqpv0abR7o passed since 7 >= 6
# LVxDfLUomW0 passed since 1 >= 1
# LYr-anCd300 passed since 2 >= 2
# LaQHEtngJlE passed since 2 >= 2
# LmMXXT4DfWk passed since 5 >= 4
# LokqEvKi-pc passed since 2 >= 2
# LokqEvKi-pc passed since 3 >= 2
# M1blnLmHPB4 passed since 6 >= 6
# M3Y9mBz6tSc passed since 2 >= 2
# MB6YFh7KTAQ passed since 1 >= 1
# MOmOgRkRWQg passed since 5 >= 5
# MOmOgRkRWQg passed since 6 >= 5
# MSBCdDaL-KQ passed since 1 >= 1
# MSCMaejQfbM passed since 5 >= 5
# Mf7WX8sEq2M passed since 1 >= 1
# N-o2udWDtI0 passed since 2 >= 2
# NGK-XEBNE7Q passed since 3 >= 3
# NZEJRwaDU2M passed since 4 >= 4
# NZEJRwaDU2M passed since 5 >= 4
# NZEJRwaDU2M passed since 6 >= 4
# NZEJRwaDU2M passed since 7 >= 4
# NZEJRwaDU2M passed since 8 >= 4
# Nqj-S6ifhC4 passed since 1 >= 1
# NuCjuBBad68 passed since 4 >= 4
# NvD0JFx2W60 passed since 1 >= 1
# OOj2eUHEu9E passed since 2 >= 2
# ORwQr3NRpUA passed since 1 >= 1
# ORwQr3NRpUA passed since 2 >= 1
# ORwQr3NRpUA passed since 3 >= 1
# ORwQr3NRpUA passed since 4 >= 1
# Or0YOxm3tOY passed since 1 >= 1
# OxoJI8uh9so passed since 1 >= 1
# P6RmP2giBTQ passed since 3 >= 3
# Pcuz2EC43Nc passed since 1 >= 1
# Q64SRgsgr_I passed since 1 >= 1
# Q64SRgsgr_I passed since 2 >= 1
# Q64SRgsgr_I passed since 3 >= 1
# QVPC800jbFo passed since 1 >= 1
# QVPC800jbFo passed since 2 >= 1
# QVPC800jbFo passed since 3 >= 1
# QgAfa9yYVTc passed since 2 >= 2
# QgAfa9yYVTc passed since 3 >= 2
# Qqtp8tqt-Ik passed since 2 >= 2
# Rvtt4WPsaOA passed since 3 >= 2
# Rvtt4WPsaOA passed since 4 >= 2
# Rvtt4WPsaOA passed since 5 >= 2
# Rvtt4WPsaOA passed since 6 >= 2
# Rvtt4WPsaOA passed since 7 >= 2
# Shi6qO85IQU passed since 6 >= 6
# SiT9VWngZMg passed since 11 >= 11
# SilqKh4rBTg passed since 1 >= 1
# Stwpy77IHEc passed since 1 >= 1
# Stwpy77IHEc passed since 2 >= 1
# SyWj2uQDTJw passed since 1 >= 1
# T4giMyqv0qc passed since 3 >= 3
# T7fzQehxz_Q passed since 1 >= 1
# THFeH8g_Hs0 passed since 1 >= 1
# TM8VR4WCVKA passed since 2 >= 2
# TkpTJnVUnpw passed since 3 >= 3
# TqfGtn5wZKM passed since 1 >= 1
# UHoyyW8hOSE passed since 2 >= 2
# URZW0x6ozog passed since 6 >= 6
# UcmaNL0IbsU passed since 1 >= 1
# UcmaNL0IbsU passed since 2 >= 1
# UcmaNL0IbsU passed since 3 >= 1
# UkzM0oR0Irg passed since 3 >= 3
# UkzM0oR0Irg passed since 4 >= 3
# UkzM0oR0Irg passed since 5 >= 3
# UkzM0oR0Irg passed since 6 >= 3
# UkzM0oR0Irg passed since 7 >= 3
# UwB7_2hwJzw passed since 1 >= 1
# V7BPIGNPL-I passed since 2 >= 2
# V8W85WjayKQ passed since 3 >= 3
# VGsgIwmdvAQ passed since 1 >= 1
# VNbTPKmKdm8 passed since 1 >= 1
# W-AvQrA1qlI passed since 1 >= 1
# W1Jj2Lb9wt8 passed since 3 >= 3
# W1Jj2Lb9wt8 passed since 4 >= 3
# W3GGzq1PIqs passed since 3 >= 3
# W79Prod-058 passed since 1 >= 1
# WWRQqjKcpVw passed since 5 >= 5
# X-vdnHl0x0A passed since 4 >= 4
# X-xVyNTXmKY passed since 2 >= 2
# X73GLwJF7Z8 passed since 4 >= 4
# X73GLwJF7Z8 passed since 5 >= 4
# XHFsmsGPDVc passed since 1 >= 1
# XHFsmsGPDVc passed since 2 >= 1
# XHFsmsGPDVc passed since 3 >= 1
# XHFsmsGPDVc passed since 4 >= 1
# XVMuN3em64c passed since 2 >= 2
# XWLh6BBJY2c passed since 2 >= 2
# XWLh6BBJY2c passed since 3 >= 2
# Xj4HQwpJRA4 passed since 6 >= 6
# XpIpHBgJUGM passed since 2 >= 2
# Y6m5YnRmWO4 passed since 1 >= 1
# Y6m5YnRmWO4 passed since 2 >= 1
# Y6m5YnRmWO4 passed since 3 >= 1
# Y6m5YnRmWO4 passed since 4 >= 1
# YAHsPetA0yM passed since 3 >= 3
# YAHsPetA0yM passed since 4 >= 3
# YM6giKk2JIs passed since 1 >= 1
# Yij4cD0wwSg passed since 2 >= 2
# Z6SJAY_kX5Q passed since 2 >= 2
# ZJLo4kKI_uw passed since 5 >= 5
# ZJLo4kKI_uw passed since 6 >= 5
# ZWBBn2Ow9Cs passed since 7 >= 7
# ZdgEwZ7xYxo passed since 2 >= 2
# Zp9pvwkC7H8 passed since 3 >= 3
# _Lyt-IwXCSo passed since 2 >= 2
# _Qtg1JGMF6U passed since 1 >= 1
# _zDiMvRtHhc passed since 1 >= 1
# a2HjLtnVDaY passed since 4 >= 4
# a2HjLtnVDaY passed since 5 >= 4
# a4TQzOsz3qY passed since 1 >= 1
# aMHCqrHTkRI passed since 1 >= 1
# akafnWXI0mo passed since 4 >= 4
# b-6ZKADToAQ passed since 3 >= 3
# bRouUWZSolE passed since 7 >= 7
# bVu0Ms6Stfc passed since 5 >= 5
# bVu0Ms6Stfc passed since 6 >= 5
# bnX78Yl2ZsI passed since 1 >= 1
# c-QiIccd9Co passed since 6 >= 6
# c-QiIccd9Co passed since 7 >= 6
# c-QiIccd9Co passed since 8 >= 6
# cHGn8l2j-e8 passed since 1 >= 1
# crZ48VB68AY passed since 1 >= 1
# crZ48VB68AY passed since 2 >= 1
# d8fKO-NPvq4 passed since 2 >= 2
# dEwSE3eg7jM passed since 2 >= 2
# dEwSE3eg7jM passed since 3 >= 2
# dEwSE3eg7jM passed since 4 >= 2
# dQVfzLc1QQg passed since 2 >= 2
# dcsSO0xHCbA passed since 1 >= 1
# eEHuss9E1LY passed since 1 >= 1
# eJk1Im2B3W0 passed since 3 >= 3
# eLZCsQSkJ7k passed since 3 >= 3
# eR6bSwdYAyk passed since 2 >= 2
# eYT78FI0UwM passed since 1 >= 1
# e_02Ks8t_0g passed since 3 >= 3
# ecD8xC8O3KU passed since 2 >= 2
# fuFuis8WT5M passed since 3 >= 3
# g3tg_c4FAas passed since 2 >= 2
# gEKcxYdx_0Y passed since 10 >= 10
# gErWZnR0ELI passed since 2 >= 2
# gc5cMErB_fA passed since 1 >= 1
# glk2zL5hvNY passed since 2 >= 2
# glk2zL5hvNY passed since 3 >= 2
# glk2zL5hvNY passed since 4 >= 2
# gnZssGiQC7A passed since 1 >= 1
# h8kGeFD2bsQ passed since 3 >= 3
# hB5mbgwjgxc passed since 2 >= 2
# hBO77JSOR04 passed since 1 >= 1
# hEnjUdp6UG0 passed since 1 >= 1
# hIw3GozP_8g passed since 1 >= 1
# hP4ji3MXpNQ passed since 2 >= 2
# hXP_wIs5Xj0 passed since 1 >= 1
# hgTpayHi-h8 passed since 5 >= 5
# ho3e2cK3Wqg passed since 3 >= 3
# iP-6CuwqE-8 passed since 3 >= 3
# iP-6CuwqE-8 passed since 4 >= 3
# iVQ0nzw-nKE passed since 1 >= 1
# if-iCCJmX44 passed since 4 >= 4
# j3_XpeMbjDc passed since 2 >= 2
# j8CWKIDNmfE passed since 4 >= 4
# jAZLmop4Reo passed since 10 >= 6
# jAZLmop4Reo passed since 6 >= 6
# jAZLmop4Reo passed since 7 >= 6
# jAZLmop4Reo passed since 8 >= 6
# jAZLmop4Reo passed since 9 >= 6
# jT6ErVkxGM4 passed since 1 >= 1
# jiWRJTeTDuk passed since 2 >= 2
# jvRnA8WoXAk passed since 1 >= 1
# jyRjjZPDy3k passed since 1 >= 1
# k-LL2KCjnV4 passed since 1 >= 1
# kgNU2YTPs6Q passed since 2 >= 2
# kgNU2YTPs6Q passed since 3 >= 2
# ko7QYFoWAvU passed since 1 >= 1
# lQflVDHtPSM passed since 2 >= 2
# ld4Kl7GzYv4 passed since 2 >= 2
# ldnLxTablA8 passed since 2 >= 2
# lgVKAM7PzuE passed since 7 >= 7
# ljpy2HKGhtk passed since 6 >= 6
# lvb7B8pd1BE passed since 5 >= 5
# lyV92G0JJQw passed since 4 >= 4
# mHFZCn-jRpE passed since 1 >= 1
# mRtieHC2u_U passed since 1 >= 1
# mUfFoPwitUg passed since 3 >= 3
# mX4J_iUxv_I passed since 7 >= 7
# mX4J_iUxv_I passed since 8 >= 7
# mdIjgGxdsm0 passed since 1 >= 1
# mzbe4DqmUzg passed since 1 >= 1
# n7ZSUqXv4mo passed since 3 >= 3
# nTNCch1B-Ok passed since 1 >= 1
# oxlsk5PcpJg passed since 4 >= 4
# pBf6ud04HNw passed since 2 >= 2
# pBf6ud04HNw passed since 3 >= 2
# pD9ro9h--Bc passed since 1 >= 1
# p_x90xpb46s passed since 1 >= 1
# pr9a2SYhx1I passed since 1 >= 1
# pwmtkiL-lVw passed since 1 >= 1
# pwmtkiL-lVw passed since 2 >= 1
# pwmtkiL-lVw passed since 3 >= 1
# q-Q51uuejuw passed since 1 >= 1
# qCit6e2MZHg passed since 1 >= 1
# qKZRQ-HQ9Cc passed since 1 >= 1
# r9wOJgzDUuY passed since 1 >= 1
# rCJXCc7DTVs passed since 1 >= 1
# rKLgTdFRG9M passed since 1 >= 1
# rcoqA78FH9A passed since 1 >= 1
# roRWQY_qIZA passed since 3 >= 3
# ruOpQBeBcng passed since 4 >= 4
# s-kTctdS0jU passed since 1 >= 1
# sDCqW7pFNfI passed since 1 >= 1
# sH900NWZrCU passed since 4 >= 4
# sH900NWZrCU passed since 5 >= 4
# sToQez6O474 passed since 1 >= 1
# sVJ1x4Mv_Vk passed since 5 >= 5
# sVJ1x4Mv_Vk passed since 6 >= 5
# sW8cLzIO9r8 passed since 1 >= 1
# sWBqfGmCF6I passed since 3 >= 3
# shBEBdUSDMU passed since 1 >= 1
# sjqLkmUnvTU passed since 8 >= 8
# sqpOl9AjsDY passed since 3 >= 3
# sqpOl9AjsDY passed since 4 >= 3
# tSwsRm-HBUM passed since 6 >= 6
# tSwsRm-HBUM passed since 7 >= 6
# tUfJLX-JfzE passed since 3 >= 3
# te3jaD1-SsQ passed since 1 >= 1
# thMckjuhTCI passed since 4 >= 4
# ub26kLEfphw passed since 2 >= 2
# ub26kLEfphw passed since 3 >= 2
# ub26kLEfphw passed since 4 >= 2
# ubCRwmhBrIo passed since 6 >= 6
# ucnR6OcpbTc passed since 1 >= 1
# ucnR6OcpbTc passed since 2 >= 1
# v2o6AxrC4cc passed since 4 >= 4
# v9GlKrSc2Zs passed since 5 >= 5
# vLzxe1hxsV4 passed since 2 >= 2
# volrav5aZ0k passed since 1 >= 1
# volrav5aZ0k passed since 2 >= 1
# w0LU1Ho4dsY passed since 3 >= 3
# w0LU1Ho4dsY passed since 4 >= 3
# w0LU1Ho4dsY passed since 5 >= 3
# w0LU1Ho4dsY passed since 6 >= 3
# w0LU1Ho4dsY passed since 7 >= 3
# wXRKzhBYmWg passed since 1 >= 1
# wXRKzhBYmWg passed since 2 >= 1
# wZEf-Bs__sU passed since 2 >= 2
# wZEf-Bs__sU passed since 3 >= 2
# whTfWGzJvHU passed since 4 >= 4
# wm5lOlOixt0 passed since 1 >= 1
# wm5lOlOixt0 passed since 2 >= 1
# wm5lOlOixt0 passed since 3 >= 1
# x7r036CXYZ4 passed since 2 >= 2
# xHZ5UEoIgTw passed since 1 >= 1
# xHjxGb0jJQ8 passed since 1 >= 1
# xJMiTiemJn0 passed since 2 >= 2
# yBa3Ib9XqQc passed since 2 >= 2
# yBa3Ib9XqQc passed since 3 >= 2
# ylzhY6Uy_Mg passed since 2 >= 2
# zOTulc5ZXCI passed since 1 >= 1
# zOTulc5ZXCI passed since 2 >= 1
# zOTulc5ZXCI passed since 3 >= 1
# zksj6YeZ-0I passed since 1 >= 1
# zksj6YeZ-0I passed since 2 >= 1
# zz8hlLcjIbQ passed since 1 >= 1
# zzM5lnGYuHY passed since 2 >= 2
# Collected video information saved to output_video_info.json
# 411
